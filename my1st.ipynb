# %% [markdown]
# <a href="https://colab.research.google.com/github/Amarnath-sahni/DSA-Code/blob/main/my1st.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# a simple way to store big data sets is to use CSV files (comma separated files).
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-91b59724-af9b-4ea7-b333-399fafae1eb1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-91b59724-af9b-4ea7-b333-399fafae1eb1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data = pd.read_csv('Data.csv')
data.head()
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0      NaN       Yes

# %%
missing_data = data.isnull().sum()
print(missing_data)
# Out:
# Country      0
# Age          1
# Salary       1
# Purchased    0
# dtype: int64

# %%
total_missing = data.isnull().sum().sum()
print(f"Total missing values in the dataset: {total_missing}")
# Out:
# Total missing values in the dataset: 2

# %%
# Out:
# Missing values before filling:
# age       1
# salary    2
# gender    1
# dtype: int64
#
# Missing values after filling:
# age       0
# salary    0
# gender    0
# dtype: int64
#
# Filled Data:
#      age   salary  gender
# 0  25.00  50000.0    Male
# 1  30.00  55000.0  Female
# 2  26.25  60000.0  Female
# 3  22.00  55000.0  Female
# 4  28.00  55000.0    Male

# %% [markdown]
# A Pandas DataFrame is a 2 dimensional data structure, like a 2 dimensional array, or a table with rows and columns.

# %%
import pandas as pd

data = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}

df = pd.DataFrame(data)
print(df)

print("-----row index no.------")
#refer to the row index:
print(df.loc[0])

#use a list of indexes:
print(df.loc[[0, 1]])

print("-----add row name------")
#Add a list of names to give each row a name:
df = pd.DataFrame(data,index =['day1', 'day2','day3'])
print(df)

print("-----loc------")
#refer to the named index
print(df.loc["day2"])
# Out:
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45
# -----row index no.------
# calories    420
# duration     50
# Name: 0, dtype: int64
#    calories  duration
# 0       420        50
# 1       380        40
# -----add row name------
#       calories  duration
# day1       420        50
# day2       380        40
# day3       390        45
# -----loc------
# calories    380
# duration     40
# Name: day2, dtype: int64

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-7da4c823-5d26-4c7b-8051-1b906aa2772b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7da4c823-5d26-4c7b-8051-1b906aa2772b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df = pd.read_csv("data.csv")

#use to_string() print entire dataframe

print(df.to_string())

#Print information about the data:
print(df.info())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112       NaN
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %%
import pandas as pd
pd.options.display.max_rows = 9999

df=pd.read_csv("data.csv")

print("he number of rows returned is defined in Pandas option settings.")
print(pd.options.display.max_rows)

print("You can change the maximum rows number with the same statement.")
print(df)
# Out:
# he number of rows returned is defined in Pandas option settings.
# 9999
# You can change the maximum rows number with the same statement.
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112       NaN
# 18         60    103       123     323.0
# ...

# %% [markdown]
# **Read JSON**
# Big data sets are often stored, or extracted as JSON.JSON is plain text, but has the format of an object, and is well known in the world of programming, including Pandas.

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-61f2c609-6bb8-4770-aeaf-52996bbc00cf" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-61f2c609-6bb8-4770-aeaf-52996bbc00cf">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df=pd.read_json('data.json')
print("==================hi===================")
print(df.to_string)

# %% [markdown]
# tail() -> **Print** the last 5 rows of the DataFrame:
# head()-> print 10rows of head
